# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
from numpy.linalg import cholesky
import os
from pandas.plotting import autocorrelation_plot


import warnings
import itertools

# Import Statsmodels
from statsmodels.tsa.api import VAR
from statsmodels.tsa.stattools import adfuller
from statsmodels.tools.eval_measures import rmse, aic

from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

import scipy.integrate as integrate
import scipy.special as special

# %%
wages_path = 'wages.xlsx'

wages = pd.read_excel(wages_path, engine='openpyxl', usecols = ['time','NSW','VIC','QLD','SA','WA','TAS','NT'])
wages = pd.DataFrame(wages)
wages = wages.set_index('time').asfreq('QS-DEC')

# Read the Excel file into a pandas DataFrame
wages_pre_covid =wages.iloc[:40]

# %%
wages_nsw = wages['NSW']
wages_vic = wages['VIC']
wages_qld = wages['QLD']
wages_sa = wages['SA']
wages_wa = wages['WA']
wages_tas = wages['TAS']
wages_nt = wages['NT']

# %%
wages.plot(figsize=(15, 6))
wages_change = wages.diff().dropna()
wages_change.plot(figsize=(15, 6))
# Out:
# <Axes: xlabel='time'>

# %%
wages_pre_covid_nsw = wages_pre_covid['NSW']
wages_pre_covid_vic = wages_pre_covid['VIC']
wages_pre_covid_qld = wages_pre_covid['QLD']
wages_pre_covid_sa = wages_pre_covid['SA']
wages_pre_covid_wa = wages_pre_covid['WA']
wages_pre_covid_tas = wages_pre_covid['TAS']
wages_pre_covid_nt = wages_pre_covid['NT']

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 18, 8
decomposition = sm.tsa.seasonal_decompose(wages_pre_covid_tas, model='additive')
decomposition.plot()
plt.show()

# %% [markdown]
# Time series forecasting with ARIMA

# %%
def adfuller_test(wage):
    result=adfuller(wage)
    labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )

    if result[1] <= 0.05:
        print("strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data is stationary")
    else:
        print("weak evidence against null hypothesis,indicating it is non-stationary ")

adfuller_test(wages_pre_covid_tas)
# Out:
# ADF Test Statistic : 0.5612838110453616
# p-value : 0.9866214301199993
# #Lags Used : 4
# Number of Observations : 35
# weak evidence against null hypothesis,indicating it is non-stationary

# %%
wages_pre_covid_tas = wages_pre_covid_tas.diff().dropna()

# %%
def adfuller_test(wage):
    result=adfuller(wage)
    labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )

    if result[1] <= 0.05:
        print("strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data is stationary")
    else:
        print("weak evidence against null hypothesis,indicating it is non-stationary ")

adfuller_test(wages_pre_covid_tas)
# Out:
# ADF Test Statistic : -2.4153772275888605
# p-value : 0.1374432523128733
# #Lags Used : 6
# Number of Observations : 32
# weak evidence against null hypothesis,indicating it is non-stationary

# %%
wages_pre_covid_tas = wages_pre_covid_tas.diff().dropna()

# %%
def adfuller_test(wage):
    result=adfuller(wage)
    labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )

    if result[1] <= 0.05:
        print("strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data is stationary")
    else:
        print("weak evidence against null hypothesis,indicating it is non-stationary ")

adfuller_test(wages_pre_covid_tas)
# Out:
# ADF Test Statistic : -24.26046198241021
# p-value : 0.0
# #Lags Used : 2
# Number of Observations : 35
# strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data is stationary

# %%
f = plt.figure()
ax1 = f.add_subplot(121)
ax1.set_title('3th order differencing')
ax1.plot(wages_pre_covid_tas)

ax2 = f.add_subplot(122)
plot_acf(wages_pre_covid_tas, ax=ax2)
plt.show()

# %% [markdown]
# As from the above observation, after the 4 order differencing, the p-value drops beyond the threshold order and shows strong evidence against the null hypothesis, sp taking "d" as 3.
#
# We see the 4th lag is the most significant. so p is 4.
#
# There are 3 lags crossed the threshold, so q is 3.

# %%
p = d = q = range(0, 2)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]
                
for param_seasonal in seasonal_pdq:
    try:
        mod = sm.tsa.statespace.SARIMAX(wages_pre_covid_tas,
                                            order=(4, 3, 3),
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)
        results  = mod.fit()
        print('ARIMA(4, 3, 3)x{}12 - AIC:{}'.format(param_seasonal, results.aic))
    except:
        continue
# Out:
# ARIMA(4, 3, 3)x(0, 0, 0, 12)12 - AIC:40.875575307715714
# ARIMA(4, 3, 3)x(0, 0, 1, 12)12 - AIC:30.43305459354736
# E:\Uni\research\venv\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# ARIMA(4, 3, 3)x(0, 1, 0, 12)12 - AIC:37.18591279724673
# E:\Uni\research\venv\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# E:\Uni\research\venv\lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# E:\Uni\research\venv\lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# E:\Uni\research\venv\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# ARIMA(4, 3, 3)x(0, 1, 1, 12)12 - AIC:15.174593816312322
# ARIMA(4, 3, 3)x(1, 0, 0, 12)12 - AIC:30.788749388307004
# E:\Uni\research\venv\lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# ARIMA(4, 3, 3)x(1, 0, 1, 12)12 - AIC:32.570181993653556
# E:\Uni\research\venv\lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# E:\Uni\research\venv\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# ARIMA(4, 3, 3)x(1, 1, 0, 12)12 - AIC:-9.31466677617324
# ARIMA(4, 3, 3)x(1, 1, 1, 12)12 - AIC:-5.663185416904611
# E:\Uni\research\venv\lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
#(p, d, q)

mod = sm.tsa.statespace.SARIMAX(wages_pre_covid_tas,
                                order=(4, 3, 3),
                                seasonal_order=(0, 1, 1, 12),
                                enforce_invertibility=False)
results = mod.fit()
print(results.summary().tables[1])
# Out:
# E:\Uni\research\venv\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.4091      7.070     -0.058      0.954     -14.267      13.448
# ar.L2         -0.2659      7.039     -0.038      0.970     -14.062      13.530
# ar.L3         -0.3708      5.937     -0.062      0.950     -12.007      11.266
# ar.L4          0.4828      6.022      0.080      0.936     -11.320      12.286
# ma.L1         -2.9131    196.132     -0.015      0.988    -387.324     381.498
# ma.L2          2.8944    408.488      0.007      0.994    -797.727     803.516
# ma.L3         -0.9802    200.635     -0.005      0.996    -394.217     392.256
# ma.S.L12      -1.1241      4.235     -0.265      0.791      -9.425       7.176
# sigma2         0.0364      7.903      0.005      0.996     -15.453      15.526
# ==============================================================================
# E:\Uni\research\venv\lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
results.plot_diagnostics(figsize=(16, 8))
plt.show()

# %%
pred = results.get_prediction(start=pd.to_datetime('2017-06-01'), dynamic=False)
pred_ci = pred.conf_int().diff().dropna()
ax = wages_pre_covid_tas['2014':].diff().dropna().plot(label='observed')

pred.predicted_mean.diff().dropna().plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 7))

ax.set_xlabel('Date')
ax.set_ylabel('Wages')
plt.legend()
plt.show()

# %%
wages_pre_covid_tas = wages_pre_covid['TAS']
wages_pre_covid_tas = wages_pre_covid_tas.diff().dropna()

mod = sm.tsa.statespace.SARIMAX(wages_pre_covid_tas,
                                order=(4, 3, 3),
                                seasonal_order=(0, 1, 1, 12),
                                enforce_invertibility=False)
results = mod.fit()
print(results.summary().tables[1])

pred_uc = results.get_forecast(steps=14)
pred_ci = pred_uc.conf_int()
ax = wages_tas.diff().dropna().plot(label='observed', figsize=(14, 7))

pred_ci["Predictions"] = pred_uc.predicted_mean
print(pred_ci)

pred_uc.predicted_mean.plot(ax=ax, label='Forecast')
ax.set_xlabel('Date')
ax.set_ylabel('Predicted change in wages')
plt.legend()
plt.show()
# Out:
# E:\Uni\research\venv\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.7678      1.563     -0.491      0.623      -3.831       2.295
# ar.L2         -0.5986      1.409     -0.425      0.671      -3.360       2.162
# ar.L3         -0.6623      1.278     -0.518      0.604      -3.167       1.843
# ar.L4          0.1630      1.323      0.123      0.902      -2.431       2.757
# ma.L1         -1.7216      7.543     -0.228      0.819     -16.506      13.063
# ma.L2          0.5664      6.444      0.088      0.930     -12.063      13.195
# ma.L3          0.2171      2.032      0.107      0.915      -3.765       4.199
# ma.S.L12      -0.8810      4.421     -0.199      0.842      -9.546       7.784
# sigma2         0.0417      0.226      0.185      0.853      -0.401       0.484
# ==============================================================================
#             lower TAS  upper TAS  Predictions
# 2020-03-01   0.546199   1.455791     1.000995
# 2020-06-01  -0.094465   0.938672     0.422104
# 2020-09-01   1.935686   3.058233     2.496959
# 2020-12-01   0.048605   1.226810     0.637707
# 2021-03-01   0.387583   2.013922     1.200752
# 2021-06-01  -0.126360   1.734107     0.803873
# 2021-09-01   1.745765   3.880096     2.812931
# 2021-12-01  -0.293630   2.060613     0.883491
# 2022-03-01  -0.000521   2.884735     1.442107
# 2022-06-01  -0.620986   2.677443     1.028228
# 2022-09-01   0.661867   4.480669     2.571268
# 2022-12-01  -1.057457   3.219675     1.081109
# 2023-03-01  -0.794824   4.350086     1.777631
# 2023-06-01  -1.834614   4.010753     1.088069
# E:\Uni\research\venv\lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
wages_pre_covid_tas = wages_pre_covid['TAS']

mod = sm.tsa.statespace.SARIMAX(wages_pre_covid_tas,
                                order=(4, 2, 1),
                                seasonal_order=(0, 1, 1, 12),
                                enforce_invertibility=False)
results = mod.fit()
print(results.summary().tables[1])

pred_uc = results.get_forecast(steps=14)
pred_ci = pred_uc.conf_int()
ax = wages_tas.plot(label='observed', figsize=(4, 2))
ax.fill_between(
    pred_ci.index, pred_ci['lower TAS'], pred_ci['upper TAS'],
    color='r', alpha=0.1
)

pred_ci["Predictions_wage"] = pred_uc.predicted_mean
print(pred_ci)


pred_uc.predicted_mean.plot(ax=ax, label='Forecast')
ax.set_xlabel('Date')
ax.set_ylabel('Predicted wages')
plt.legend()

plt.savefig('TAS predicted PWI.png')

plt.show()
# Out:
# E:\Uni\research\venv\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.9055      0.993     -0.912      0.362      -2.852       1.041
# ar.L2         -0.7102      0.827     -0.859      0.391      -2.332       0.911
# ar.L3         -0.7511      0.669     -1.123      0.262      -2.062       0.560
# ar.L4          0.0526      0.900      0.059      0.953      -1.711       1.816
# ma.L1          0.2878      0.964      0.299      0.765      -1.602       2.177
# ma.S.L12      -1.0758      6.755     -0.159      0.873     -14.316      12.164
# sigma2         0.0301      0.205      0.147      0.883      -0.371       0.431
# ==============================================================================
#              lower TAS   upper TAS  Predictions_wage
# 2020-03-01  135.986004  136.816583        136.401294
# 2020-06-01  135.946901  137.351335        136.649118
# 2020-09-01  137.979004  139.910748        138.944876
# 2020-12-01  138.175262  140.542574        139.358918
# 2021-03-01  138.696652  141.831472        140.264062
# 2021-06-01  138.741792  142.646347        140.694069
# 2021-09-01  140.741109  145.449458        143.095283
# 2021-12-01  140.810405  146.241273        143.525839
# 2022-03-01  141.287978  147.636833        144.462406
# 2022-06-01  141.266455  148.538985        144.902720
# 2022-09-01  142.714901  150.978605        146.846753
# 2022-12-01  142.642098  151.833493        147.237796
# 2023-03-01  143.066562  153.431438        148.249000
# 2023-06-01  142.678304  154.218701        148.448502
# E:\Uni\research\venv\lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
