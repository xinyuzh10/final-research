# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
from numpy.linalg import cholesky
import os
from pandas.plotting import autocorrelation_plot


import warnings
import itertools

# Import Statsmodels
from statsmodels.tsa.api import VAR
from statsmodels.tsa.stattools import adfuller
from statsmodels.tools.eval_measures import rmse, aic

from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

import scipy.integrate as integrate
import scipy.special as special

# %%
wages_path = 'wages.xlsx'

wages = pd.read_excel(wages_path, engine='openpyxl', usecols = ['time','NSW','VIC','QLD','SA','WA','TAS','NT'])
wages = pd.DataFrame(wages)
wages = wages.set_index('time').asfreq('QS-DEC')

# Read the Excel file into a pandas DataFrame
wages_pre_covid =wages.iloc[:40]
wages_during_covid =wages.iloc[40:52]
wages_post_covid =wages.iloc[52:]

# %%
wages_nsw = wages['NSW']
wages_vic = wages['VIC']
wages_qld = wages['QLD']
wages_sa = wages['SA']
wages_wa = wages['WA']
wages_tas = wages['TAS']
wages_nt = wages['NT']

# %%
wages.plot(figsize=(15, 6))
wages_change = wages.diff().dropna()
wages_change.plot(figsize=(15, 6))
# Out:
# <Axes: xlabel='time'>

# %%
wages_pre_covid_nsw = wages_pre_covid['NSW']
wages_pre_covid_vic = wages_pre_covid['VIC']
wages_pre_covid_qld = wages_pre_covid['QLD']
wages_pre_covid_sa = wages_pre_covid['SA']
wages_pre_covid_wa = wages_pre_covid['WA']
wages_pre_covid_tas = wages_pre_covid['TAS']
wages_pre_covid_nt = wages_pre_covid['NT']

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 18, 8
decomposition = sm.tsa.seasonal_decompose(wages_pre_covid_vic, model='additive')
decomposition.plot()
plt.show()

# %% [markdown]
# Time series forecasting with ARIMA

# %%
def adfuller_test(wage):
    result=adfuller(wage)
    labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )

    if result[1] <= 0.05:
        print("strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data is stationary")
    else:
        print("weak evidence against null hypothesis,indicating it is non-stationary ")

adfuller_test(wages_pre_covid_vic)
# Out:
# ADF Test Statistic : -0.20044373575516888
# p-value : 0.9384687046383722
# #Lags Used : 6
# Number of Observations : 33
# weak evidence against null hypothesis,indicating it is non-stationary

# %%
wages_pre_covid_vic = wages_pre_covid_vic.diff().dropna()

# %%
f = plt.figure()
ax1 = f.add_subplot(121)
ax1.set_title('1st order differencing')
ax1.plot(wages_pre_covid_vic)

ax2 = f.add_subplot(122)
plot_acf(wages_pre_covid_vic, ax=ax2)
plt.show()

# %% [markdown]
# As from the above observation, after the first order differencing, the p-value drops beyond the threshold order and shows strong evidence against the null hypothesis, sp taking "d" as 2.
#
# We see the 4th lag is the most significant. so p is 4.
#
# There are 2 lags crossed the threshold, so q is 1.

# %%
p = d = q = range(0, 2)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]
                
for param_seasonal in seasonal_pdq:
    try:
        mod = sm.tsa.statespace.SARIMAX(wages_pre_covid_vic,
                                            order=(4, 2, 1),
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)
        results  = mod.fit()
        print('ARIMA(4, 2, 1)x{}12 - AIC:{}'.format(param_seasonal, results.aic))
    except:
        continue
# Out:
# ARIMA(4, 2, 1)x(0, 0, 0, 12)12 - AIC:-8.791336937995315
# ARIMA(4, 2, 1)x(0, 0, 1, 12)12 - AIC:1174.8860430166578
# ARIMA(4, 2, 1)x(0, 1, 0, 12)12 - AIC:-4.969658835053963
# E:\Uni\research\venv\lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# E:\Uni\research\venv\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# ARIMA(4, 2, 1)x(0, 1, 1, 12)12 - AIC:-3.0883767968932503
# ARIMA(4, 2, 1)x(1, 0, 0, 12)12 - AIC:-6.605865502322217
# ARIMA(4, 2, 1)x(1, 0, 1, 12)12 - AIC:-6.245543571574068
# ARIMA(4, 2, 1)x(1, 1, 0, 12)12 - AIC:-0.02115190906190456
# ARIMA(4, 2, 1)x(1, 1, 1, 12)12 - AIC:1.97870786765289
# E:\Uni\research\venv\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'

# %%
#(p, d, q)

mod = sm.tsa.statespace.SARIMAX(wages_pre_covid_vic,
                                order=(4, 2, 1),
                                seasonal_order=(1, 1, 0, 12),
                                enforce_invertibility=False)
results = mod.fit()
print(results.summary().tables[1])
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.3723      0.202     -6.783      0.000      -1.769      -0.976
# ar.L2         -1.5669      0.298     -5.260      0.000      -2.151      -0.983
# ar.L3         -1.1589      0.364     -3.180      0.001      -1.873      -0.445
# ar.L4         -0.5825      0.289     -2.014      0.044      -1.149      -0.016
# ma.L1         -1.1908      0.451     -2.638      0.008      -2.076      -0.306
# ar.S.L12      -0.4254      0.273     -1.556      0.120      -0.961       0.110
# sigma2         0.0240      0.016      1.543      0.123      -0.007       0.055
# ==============================================================================

# %%
results.plot_diagnostics(figsize=(16, 8))
plt.show()

# %%
pred = results.get_prediction(start=pd.to_datetime('2017-06-01'), dynamic=False)
pred_ci = pred.conf_int().diff().dropna()
ax = wages_pre_covid_vic['2014':].diff().dropna().plot(label='observed')

pred.predicted_mean.diff().dropna().plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 7))

ax.set_xlabel('Date')
ax.set_ylabel('Wages')
plt.legend()
plt.show()

# %%
pred_uc = results.get_forecast(steps=14)
pred_ci = pred_uc.conf_int()
ax = wages_vic.diff().dropna().plot(label='observed', figsize=(14, 7))

pred_ci["Predictions"] = pred_uc.predicted_mean
print(pred_ci)

pred_uc.predicted_mean.plot(ax=ax, label='Forecast')
ax.set_xlabel('Date')
ax.set_ylabel('Predicted change in wages')
plt.legend()
plt.show()
# Out:
#             lower VIC  upper VIC  Predictions
# 2020-03-01   0.530741   1.255321     0.893031
# 2020-06-01   0.426469   1.166659     0.796564
# 2020-09-01   1.029123   1.769966     1.399545
# 2020-12-01   0.813345   1.670054     1.241700
# 2021-03-01   0.443218   1.352800     0.898009
# 2021-06-01   0.663456   1.611245     1.137351
# 2021-09-01   1.100118   2.049697     1.574907
# 2021-12-01   0.984307   2.027980     1.506144
# 2022-03-01   0.597161   1.745401     1.171281
# 2022-06-01   0.664108   1.831337     1.247722
# 2022-09-01   1.040005   2.248285     1.644145
# 2022-12-01   0.863010   2.148999     1.506004
# 2023-03-01   0.783004   2.365991     1.574498
# 2023-06-01   0.673983   2.281379     1.477681

# %%
wages_pre_covid_vic = wages_pre_covid['VIC']

mod = sm.tsa.statespace.SARIMAX(wages_pre_covid_vic,
                                order=(4, 2, 1),
                                seasonal_order=(1, 1, 0, 12),
                                enforce_invertibility=False)
results = mod.fit()
print(results.summary().tables[1])

pred_uc = results.get_forecast(steps=14)
pred_ci = pred_uc.conf_int()
ax = wages_vic.plot(label='observed', figsize=(4, 2))
ax.fill_between(
    pred_ci.index, pred_ci['lower VIC'], pred_ci['upper VIC'],
    color='r', alpha=0.1
)
pred_ci["Predictions_wage"] = pred_uc.predicted_mean
print(pred_ci)

pred_uc.predicted_mean.plot(ax=ax, label='Forecast')
ax.set_xlabel('Date')
ax.set_ylabel('Predicted wage')
plt.legend()

plt.savefig('VIC predicted PWI.png')

plt.show()
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.4569      0.597     -2.441      0.015      -2.627      -0.287
# ar.L2         -1.4929      0.588     -2.541      0.011      -2.644      -0.341
# ar.L3         -1.0328      0.633     -1.632      0.103      -2.273       0.208
# ar.L4         -0.4692      0.404     -1.161      0.246      -1.261       0.323
# ma.L1          0.4465      0.679      0.658      0.511      -0.884       1.777
# ar.S.L12      -0.2419      0.445     -0.544      0.587      -1.114       0.630
# sigma2         0.0482      0.025      1.944      0.052      -0.000       0.097
# ==============================================================================
#              lower VIC   upper VIC  Predictions_wage
# 2020-03-01  134.423559  135.284190        134.853875
# 2020-06-01  134.908963  136.119783        135.514373
# 2020-09-01  136.038495  137.503546        136.771021
# 2020-12-01  136.843373  138.758477        137.800925
# 2021-03-01  137.248088  139.698459        138.473273
# 2021-06-01  137.791674  140.811768        139.301721
# 2021-09-01  138.855607  142.379252        140.617429
# 2021-12-01  139.723173  143.844427        141.783800
# 2022-03-01  140.146571  144.943874        142.545223
# 2022-06-01  140.688760  146.142219        143.415489
# 2022-09-01  141.536975  147.670174        144.603574
# 2022-12-01  142.198249  149.050398        145.624323
# 2023-03-01  142.588532  150.512873        146.550702
# 2023-06-01  142.910828  151.863107        147.386967
# E:\Uni\research\venv\lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
