# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
from numpy.linalg import cholesky
import os
from pandas.plotting import autocorrelation_plot


import warnings
import itertools

# Import Statsmodels
from statsmodels.tsa.api import VAR
from statsmodels.tsa.stattools import adfuller
from statsmodels.tools.eval_measures import rmse, aic

from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

import scipy.integrate as integrate
import scipy.special as special

# %%
wages_path = 'wages.xlsx'

wages = pd.read_excel(wages_path, engine='openpyxl', usecols = ['time','NSW','VIC','QLD','SA','WA','TAS','NT'])
wages = pd.DataFrame(wages)
wages = wages.set_index('time').asfreq('QS-DEC')

# Read the Excel file into a pandas DataFrame
wages_pre_covid =wages.iloc[:40]

# %%
wages_nsw = wages['NSW']
wages_vic = wages['VIC']
wages_qld = wages['QLD']
wages_sa = wages['SA']
wages_wa = wages['WA']
wages_tas = wages['TAS']
wages_nt = wages['NT']

# %%
wages.plot(figsize=(15, 6))
wages_change = wages.diff().dropna()
wages_change.plot(figsize=(15, 6))
# Out:
# <Axes: xlabel='time'>

# %%
wages_pre_covid_nsw = wages_pre_covid['NSW']
wages_pre_covid_vic = wages_pre_covid['VIC']
wages_pre_covid_qld = wages_pre_covid['QLD']
wages_pre_covid_sa = wages_pre_covid['SA']
wages_pre_covid_wa = wages_pre_covid['WA']
wages_pre_covid_tas = wages_pre_covid['TAS']
wages_pre_covid_nt = wages_pre_covid['NT']

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 18, 8
decomposition = sm.tsa.seasonal_decompose(wages_pre_covid_sa, model='additive')
decomposition.plot()
plt.show()

# %% [markdown]
# Time series forecasting with ARIMA

# %%
def adfuller_test(wage):
    result=adfuller(wage)
    labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )

    if result[1] <= 0.05:
        print("strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data is stationary")
    else:
        print("weak evidence against null hypothesis,indicating it is non-stationary ")

adfuller_test(wages_pre_covid_sa)
# Out:
# ADF Test Statistic : -1.0134772367152447
# p-value : 0.7483171055350162
# #Lags Used : 7
# Number of Observations : 32
# weak evidence against null hypothesis,indicating it is non-stationary

# %%
wages_pre_covid_sa = wages_pre_covid_sa.diff().dropna()

# %%
def adfuller_test(wage):
    result=adfuller(wage)
    labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )

    if result[1] <= 0.05:
        print("strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data is stationary")
    else:
        print("weak evidence against null hypothesis,indicating it is non-stationary ")

adfuller_test(wages_pre_covid_sa)
# Out:
# ADF Test Statistic : -1.566876121057136
# p-value : 0.5002080675090509
# #Lags Used : 6
# Number of Observations : 32
# weak evidence against null hypothesis,indicating it is non-stationary

# %%
wages_pre_covid_sa = wages_pre_covid_sa.diff().dropna()

# %%
def adfuller_test(wage):
    result=adfuller(wage)
    labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )

    if result[1] <= 0.05:
        print("strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data is stationary")
    else:
        print("weak evidence against null hypothesis,indicating it is non-stationary ")

adfuller_test(wages_pre_covid_sa)
# Out:
# ADF Test Statistic : -1.575286714812392
# p-value : 0.495994783669441
# #Lags Used : 5
# Number of Observations : 32
# weak evidence against null hypothesis,indicating it is non-stationary

# %%
wages_pre_covid_sa = wages_pre_covid_sa.diff().dropna()

# %%
def adfuller_test(wage):
    result=adfuller(wage)
    labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )

    if result[1] <= 0.05:
        print("strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data is stationary")
    else:
        print("weak evidence against null hypothesis,indicating it is non-stationary ")

adfuller_test(wages_pre_covid_sa)
# Out:
# ADF Test Statistic : -10.001901224151206
# p-value : 1.8746486714143638e-17
# #Lags Used : 4
# Number of Observations : 32
# strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data is stationary

# %%
f = plt.figure()
ax1 = f.add_subplot(121)
ax1.set_title('4th order differencing')
ax1.plot(wages_pre_covid_sa)

ax2 = f.add_subplot(122)
plot_acf(wages_pre_covid_sa, ax=ax2)
plt.show()

# %% [markdown]
# As from the above observation, after the 4 order differencing, the p-value drops beyond the threshold order and shows strong evidence against the null hypothesis, sp taking "d" as 4.
#
# We see the 4th lag is the most significant. so p is 4.
#
# There are 3 lags crossed the threshold, so q is 3.

# %%
p = d = q = range(0, 2)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]
                
for param_seasonal in seasonal_pdq:
    try:
        mod = sm.tsa.statespace.SARIMAX(wages_pre_covid_sa,
                                            order=(4, 4, 3),
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)
        results  = mod.fit()
        print('ARIMA(4, 4, 3)x{}12 - AIC:{}'.format(param_seasonal, results.aic))
    except:
        continue
# Out:
# ARIMA(4, 4, 3)x(0, 0, 0, 12)12 - AIC:62.944977480181066
# E:\Uni\research\venv\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# E:\Uni\research\venv\lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# ARIMA(4, 4, 3)x(0, 0, 1, 12)12 - AIC:33.997234887198324
# ARIMA(4, 4, 3)x(0, 1, 0, 12)12 - AIC:51.79642076650574
# E:\Uni\research\venv\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# E:\Uni\research\venv\lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# ARIMA(4, 4, 3)x(0, 1, 1, 12)12 - AIC:8.800982538454228
# E:\Uni\research\venv\lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# E:\Uni\research\venv\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# ARIMA(4, 4, 3)x(1, 0, 0, 12)12 - AIC:40.61031491895701
# E:\Uni\research\venv\lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# ARIMA(4, 4, 3)x(1, 0, 1, 12)12 - AIC:57.50080600595997
# E:\Uni\research\venv\lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# E:\Uni\research\venv\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# ARIMA(4, 4, 3)x(1, 1, 0, 12)12 - AIC:-5.397408410268348
# ARIMA(4, 4, 3)x(1, 1, 1, 12)12 - AIC:4.167368946020115
# E:\Uni\research\venv\lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
#(p, d, q)

mod = sm.tsa.statespace.SARIMAX(wages_pre_covid_sa,
                                order=(4, 4, 3),
                                seasonal_order=(1, 1, 1, 12),
                                enforce_invertibility=False)
results = mod.fit()
print(results.summary().tables[1])
# Out:
# E:\Uni\research\venv\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.8129      3.459     -0.524      0.600      -8.593       4.967
# ar.L2         -2.5492      6.046     -0.422      0.673     -14.399       9.301
# ar.L3         -1.7851      5.226     -0.342      0.733     -12.028       8.458
# ar.L4         -0.9794      2.742     -0.357      0.721      -6.354       4.395
# ma.L1         -0.7210      2.205     -0.327      0.744      -5.042       3.600
# ma.L2          0.3622      2.775      0.131      0.896      -5.076       5.801
# ma.L3         -0.7660      2.054     -0.373      0.709      -4.793       3.261
# ar.S.L12       0.0373     23.553      0.002      0.999     -46.126      46.201
# ma.S.L12       1.1812    184.532      0.006      0.995    -360.494     362.857
# sigma2         0.2343     49.002      0.005      0.996     -95.808      96.276
# ==============================================================================
# E:\Uni\research\venv\lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
results.plot_diagnostics(figsize=(16, 8))
plt.show()

# %%
pred = results.get_prediction(start=pd.to_datetime('2017-06-01'), dynamic=False)
pred_ci = pred.conf_int().diff().dropna()
ax = wages_pre_covid_sa['2014':].diff().dropna().plot(label='observed')

pred.predicted_mean.diff().dropna().plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 7))

ax.set_xlabel('Date')
ax.set_ylabel('Wages')
plt.legend()
plt.show()

# %%
wages_pre_covid_sa = wages_pre_covid['SA']
wages_pre_covid_sa = wages_pre_covid_sa.diff().dropna()

mod = sm.tsa.statespace.SARIMAX(wages_pre_covid_sa,
                                order=(4, 2, 1),
                                seasonal_order=(0, 0, 0, 12),
                                enforce_invertibility=False)
results = mod.fit()
print(results.summary().tables[1])

pred_uc = results.get_forecast(steps=14)
pred_ci = pred_uc.conf_int()
ax = wages_sa.diff().dropna().plot(label='observed', figsize=(14, 7))

pred_ci["Predictions"] = pred_uc.predicted_mean
print(pred_ci)

pred_uc.predicted_mean.plot(ax=ax, label='Forecast')
ax.set_xlabel('Date')
ax.set_ylabel('Predicted change in wages')
plt.legend()
plt.show()
# Out:
# E:\Uni\research\venv\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# E:\Uni\research\venv\lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.3020      0.282     -4.621      0.000      -1.854      -0.750
# ar.L2         -1.2999      0.309     -4.204      0.000      -1.906      -0.694
# ar.L3         -1.2445      0.284     -4.384      0.000      -1.801      -0.688
# ar.L4         -0.2753      0.291     -0.946      0.344      -0.846       0.295
# ma.L1         -1.3031      0.328     -3.975      0.000      -1.946      -0.661
# sigma2         0.0221      0.012      1.822      0.068      -0.002       0.046
# ==============================================================================
#             lower SA  upper SA  Predictions
# 2020-03-01  0.277825  1.037744     0.657784
# 2020-06-01  0.066132  0.827875     0.447003
# 2020-09-01  1.536038  2.322154     1.929096
# 2020-12-01  0.172366  0.974622     0.573494
# 2021-03-01  0.152719  1.330595     0.741657
# 2021-06-01  0.018865  1.199847     0.609356
# 2021-09-01  1.339157  2.566816     1.952987
# 2021-12-01  0.014603  1.286394     0.650498
# 2022-03-01  0.031690  1.626253     0.828971
# 2022-06-01 -0.040332  1.570166     0.764917
# 2022-09-01  1.138423  2.818199     1.978311
# 2022-12-01 -0.147170  1.605602     0.729216
# 2023-03-01 -0.105213  1.944606     0.919696
# 2023-06-01 -0.127326  1.955117     0.913895

# %%
wages_pre_covid_sa = wages_pre_covid['SA']

mod = sm.tsa.statespace.SARIMAX(wages_pre_covid_sa,
                                order=(4, 2, 1),
                                seasonal_order=(0, 0, 0, 12),
                                enforce_invertibility=False)
results = mod.fit()
print(results.summary().tables[1])

pred_uc = results.get_forecast(steps=14)
pred_ci = pred_uc.conf_int()
ax = wages_sa.plot(label='observed', figsize=(4, 2))
ax.fill_between(
    pred_ci.index, pred_ci['lower SA'], pred_ci['upper SA'],
    color='r', alpha=0.1
)
pred_ci["Predictions"] = pred_uc.predicted_mean
print(pred_ci)

pred_uc.predicted_mean.plot(ax=ax, label='Forecast')
ax.set_xlabel('Date')
ax.set_ylabel('Predicted wages')
plt.legend()
plt.savefig('SA predicted PWI.png')

plt.show()
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.2258      1.638     -0.138      0.890      -3.437       2.986
# ar.L2         -0.1799      1.664     -0.108      0.914      -3.440       3.081
# ar.L3         -0.1343      1.622     -0.083      0.934      -3.314       3.045
# ar.L4          0.7723      1.533      0.504      0.614      -2.232       3.777
# ma.L1         -0.7716      1.670     -0.462      0.644      -4.045       2.502
# sigma2         0.0361      0.009      4.048      0.000       0.019       0.054
# ==============================================================================
#               lower SA    upper SA  Predictions
# 2020-03-01  134.153265  134.897914   134.525590
# 2020-06-01  134.400602  135.455074   134.927838
# 2020-09-01  136.120640  137.433599   136.777119
# 2020-12-01  136.456820  138.017596   137.237208
# 2021-03-01  136.680597  138.893322   137.786959
# 2021-06-01  136.922869  139.630560   138.276714
# 2021-09-01  138.490078  141.646090   140.068084
# 2021-12-01  138.692048  142.290822   140.491435
# 2022-03-01  138.897077  143.236530   141.066804
# 2022-06-01  139.152278  144.113215   141.632747
# 2022-09-01  140.587979  146.137053   143.362516
# 2022-12-01  140.683549  146.824961   143.754255
# 2023-03-01  140.872911  147.841871   144.357391
# 2023-06-01  141.142712  148.837026   144.989869
# E:\Uni\research\venv\lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
